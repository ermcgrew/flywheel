# %%
import pandas as pd
df_study=pd.read_csv("PETSEssionList_with_study.csv")
df_study.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDDID          553 non-null    float64
#  1   PETDate         553 non-null    object
#  2   AgeatPET        516 non-null    float64
#  3   StudyID         411 non-null    object
#  4   PETProtocol     553 non-null    object
#  5   PETScannerUsed  535 non-null    object
#  6   PI-2620_Group   0 non-null      float64
#  7   PETTracer       529 non-null    object
#  8   Unnamed: 8      37 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 39.0+ KB

# %%
df_study.head(20)
# Out:
#       INDDID     PETDate  AgeatPET     StudyID PETProtocol  \
# 0   126535.0   8/10/2022      69.0         NaN       ABCD2
# 1   128147.0    9/1/2022      68.0  844403-006       ABCD2
# 2   128279.0    8/2/2022      70.0  844403-002       ABCD2
# 3   128281.0    7/6/2022      75.0  844403-001       ABCD2
# 4   128301.0   8/24/2022      88.0         NaN       ABCD2
# 5   128387.0   8/30/2022      68.0  844403-005       ABCD2
# 6   128391.0   9/27/2022      71.0  844403-007       ABCD2
# 7   128394.0  10/25/2022      70.0         NaN       ABCD2
# 8   128504.0   11/2/2022      69.0         NaN       ABCD2
# 9   128771.0   11/1/2022      66.0         NaN       ABCD2
# 10  128922.0   11/1/2022      75.0         NaN       ABCD2
# 11  126535.0   6/28/2022      68.0      126535       ABCD2
# 12  128147.0   5/11/2022      68.0         NaN       ABCD2
# 13  128267.0   9/20/2022      66.0         NaN       ABCD2
# 14  128279.0   6/15/2022      69.0         NaN       ABCD2
# ...

# %%
df_study['INDDID']=df_study['INDDID'].astype(int).astype(str)
df_study['PETDate']=df_study['PETDate'].astype(str)

# %%
df_study
# Out:
#      INDDID     PETDate  AgeatPET     StudyID     PETProtocol  \
# 0    126535   8/10/2022      69.0         NaN           ABCD2
# 1    128147    9/1/2022      68.0  844403-006           ABCD2
# 2    128279    8/2/2022      70.0  844403-002           ABCD2
# 3    128281    7/6/2022      75.0  844403-001           ABCD2
# 4    128301   8/24/2022      88.0         NaN           ABCD2
# ..      ...         ...       ...         ...             ...
# 548  122139   6/27/2019       NaN         NaN  Clinical Trial
# 549  122701   12/1/2017       NaN         NaN  Clinical Trial
# 550  122946  12/15/2017       NaN         NaN  Clinical Trial
# 551  111275   5/14/2019       NaN         NaN            ADNI
# 552  121520   4/26/2017       NaN         NaN           IDEAS
#
#             PETScannerUsed  PI-2620_Group                    PETTracer  \
# 0    Philips Ingenuity PET            NaN  AV1451 (tau) Penn Cyclotron
# 1    Philips Ingenuity PET            NaN  AV1451 (tau) Penn Cyclotron
# ...

# %%
# 118923, 09/25/2017
df_study.loc[df_study['PETDate']=='9/25/2017']
# Out:
#      INDDID    PETDate  AgeatPET  StudyID         PETProtocol  \
# 491  118923  9/25/2017      67.0  9302601  REVEAL-SCAN 825741
#
#             PETScannerUsed  PI-2620_Group              PETTracer Unnamed: 8
# 491  Philips Ingenuity PET            NaN  Florbetapir (amyloid)        NaN

# %%
# 119035, 08/01/2017
df_study.loc[df_study['PETDate']=='8/1/2017']
# Out:
#      INDDID   PETDate  AgeatPET  StudyID         PETProtocol  \
# 238  117358  8/1/2017      72.0   API-15            NACC_API
# 492  119035  8/1/2017      73.0  9302301  REVEAL-SCAN 825741
#
#             PETScannerUsed  PI-2620_Group              PETTracer Unnamed: 8
# 238  Philips Ingenuity PET            NaN  Florbetaben (amyloid)        NaN
# 492  Philips Ingenuity PET            NaN  Florbetapir (amyloid)        NaN

# %%
# 124305x20190313xFBBPETx session to: 124305x20190313xFBBPETxABC
df_study.loc[df_study['PETDate']=='3/13/2019']
# Out:
#      INDDID    PETDate  AgeatPET  StudyID         PETProtocol  \
# 507  124305  3/13/2019      71.0  9310801  REVEAL-SCAN 825741
#
#             PETScannerUsed  PI-2620_Group              PETTracer Unnamed: 8
# 507  Philips Ingenuity PET            NaN  Florbetapir (amyloid)        NaN

# %%
df_study.loc[df_study['INDDID']=='115582.02']
# Out:
# Empty DataFrame
# Columns: [INDDID, PETDate, AgeatPET, StudyID, PETProtocol, PETScannerUsed, PI-2620_Group, PETTracer, Unnamed: 8]
# Index: []
