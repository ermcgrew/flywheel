# %%
import pandas as pd
df_study=pd.read_csv("PETSEssionList_with_study.csv")
df_study.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDDID          553 non-null    float64
#  1   PETDate         553 non-null    object
#  2   AgeatPET        516 non-null    float64
#  3   StudyID         411 non-null    object
#  4   PETProtocol     553 non-null    object
#  5   PETScannerUsed  535 non-null    object
#  6   PI-2620_Group   0 non-null      float64
#  7   PETTracer       529 non-null    object
#  8   Unnamed: 8      37 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 39.0+ KB

# %%
df_study[df_study.duplicated(subset=['INDDID','PETDate'],keep=False)]
# Out:
#         INDDID  PETDate  AgeatPET  StudyID         PETProtocol  \
# 55   111275.01   6/5/19      74.0      NaN                ADNI
# 75   111275.01  5/14/19      74.0      NaN                ADNI
# 77   111487.00  4/23/19      70.0      NaN                ADNI
# 197  105476.01   5/3/18      79.0   API-60            NACC_API
# 202  106721.01  10/3/17      85.0   API-27            NACC_API
# 484  115582.02  5/12/17      69.0  9301501  REVEAL-SCAN 825741
# 517  106721.01  10/3/17       NaN      NaN            NACC_API
# 519  115582.02  5/12/17       NaN      NaN  REVEAL-SCAN 825741
# 526  105476.01   5/3/18       NaN      NaN            NACC_API
# 530  111487.00  4/23/19       NaN      NaN                ADNI
# 542  122701.00  12/1/17       NaN      NaN      Clinical Trial
# 543  122139.00  6/27/19       NaN      NaN      Clinical Trial
# 544  119655.00   1/3/19       NaN      NaN      Clinical Trial
# 545  111275.01   6/5/19       NaN      NaN                ADNI
# ...

# %%
df_study['INDDID']=df_study['INDDID'].astype(str)

# %%
df_study['INDDID'].str.len()
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 548    8
# 549    8
# 550    8
# 551    9
# 552    8
# Name: INDDID, Length: 553, dtype: int64

# %%
df_study[df_study['INDDID'].str.len()==9]
# Out:
#         INDDID   PETDate  AgeatPET   StudyID         PETProtocol  \
# 42   106722.01   6/14/06      75.0  022-0066                ADNI
# 43   106722.01    4/3/09      77.0       NaN                ADNI
# 52   104504.01   3/16/17      90.0  022-0096                ADNI
# 53   104504.01   3/12/19      92.0       NaN                ADNI
# 54   111275.01    5/9/17      71.0       NaN                ADNI
# 55   111275.01    6/5/19      74.0       NaN                ADNI
# 62   104504.01    3/2/21      94.0       NaN                ADNI
# 69   104504.01    2/1/11      84.0       NaN                ADNI
# 70   104504.01    3/6/17      90.0  022-0096                ADNI
# 71   104504.01   3/19/19      92.0       NaN                ADNI
# 72   104504.01   3/31/21      94.0       NaN                ADNI
# 73   105732.01   3/18/14      79.0       NaN                ADNI
# 75   111275.01   5/14/19      74.0       NaN                ADNI
# ...

# %%
# df.drop(df[(df['Unit_Price'] >400) & (df['Unit_Price'] < 600)].index, inplace=True)
df_study.drop(df_study[df_study['INDDID'].str.len()==9].index,inplace=True)

# %%
df_study.tail()
# Out:
#        INDDID   PETDate  AgeatPET StudyID     PETProtocol  \
# 547  119655.0    1/3/19       NaN     NaN        NACC_TPI
# 548  122139.0   6/27/19       NaN     NaN  Clinical Trial
# 549  122701.0   12/1/17       NaN     NaN  Clinical Trial
# 550  122946.0  12/15/17       NaN     NaN  Clinical Trial
# 552  121520.0   4/26/17       NaN     NaN           IDEAS
#
#             PETScannerUsed  PI-2620_Group              PETTracer Unnamed: 8
# 547  Philips Ingenuity PET            NaN  Florbetapir (amyloid)      Dave2
# 548  Philips Ingenuity PET            NaN  Florbetapir (amyloid)      Dave2
# 549  Philips Ingenuity PET            NaN  Florbetapir (amyloid)      Dave2
# 550  Philips Ingenuity PET            NaN  Florbetapir (amyloid)      Dave2
# 552                    NaN            NaN  Florbetaben (amyloid)      Dave2

# %%
# df_study['INDDID'].values()#[0:6]
df_study['INDDID']=df_study['INDDID'].str.split('.').str[0]
df_study.tail()
# Out:
#      INDDID   PETDate  AgeatPET StudyID     PETProtocol  \
# 547  119655    1/3/19       NaN     NaN        NACC_TPI
# 548  122139   6/27/19       NaN     NaN  Clinical Trial
# 549  122701   12/1/17       NaN     NaN  Clinical Trial
# 550  122946  12/15/17       NaN     NaN  Clinical Trial
# 552  121520   4/26/17       NaN     NaN           IDEAS
#
#             PETScannerUsed  PI-2620_Group              PETTracer Unnamed: 8
# 547  Philips Ingenuity PET            NaN  Florbetapir (amyloid)      Dave2
# 548  Philips Ingenuity PET            NaN  Florbetapir (amyloid)      Dave2
# 549  Philips Ingenuity PET            NaN  Florbetapir (amyloid)      Dave2
# 550  Philips Ingenuity PET            NaN  Florbetapir (amyloid)      Dave2
# 552                    NaN            NaN  Florbetaben (amyloid)      Dave2

# %%
df_study['INDDID']=df_study['INDDID'].astype(str)
df_study['PETDate']=df_study['PETDate'].astype(str)

# %%
df_study
# Out:
#         INDDID     PETDate  AgeatPET     StudyID     PETProtocol  \
# 0     126535.0   8/10/2022      69.0         NaN           ABCD2
# 1     128147.0    9/1/2022      68.0  844403-006           ABCD2
# 2     128279.0    8/2/2022      70.0  844403-002           ABCD2
# 3     128281.0    7/6/2022      75.0  844403-001           ABCD2
# 4     128301.0   8/24/2022      88.0         NaN           ABCD2
# ..         ...         ...       ...         ...             ...
# 548   122139.0   6/27/2019       NaN         NaN  Clinical Trial
# 549   122701.0   12/1/2017       NaN         NaN  Clinical Trial
# 550   122946.0  12/15/2017       NaN         NaN  Clinical Trial
# 551  111275.01   5/14/2019       NaN         NaN            ADNI
# 552   121520.0   4/26/2017       NaN         NaN           IDEAS
#
#             PETScannerUsed  PI-2620_Group                    PETTracer  \
# 0    Philips Ingenuity PET            NaN  AV1451 (tau) Penn Cyclotron
# ...

# %%
# df_study['INDDID']=df_study['INDDID'].str.replace(".01","x01")
# df_study['INDDID']=df_study['INDDID'].str.replace(".02","x02")
df_study['INDDID']=df_study['INDDID'].str.replace(".","x")
df_study
# Out:
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_8739/3965365880.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_study['INDDID']=df_study['INDDID'].str.replace(".","x")
#         INDDID     PETDate  AgeatPET     StudyID     PETProtocol  \
# 0     126535x0   8/10/2022      69.0         NaN           ABCD2
# 1     128147x0    9/1/2022      68.0  844403-006           ABCD2
# 2     128279x0    8/2/2022      70.0  844403-002           ABCD2
# 3     128281x0    7/6/2022      75.0  844403-001           ABCD2
# 4     128301x0   8/24/2022      88.0         NaN           ABCD2
# ..         ...         ...       ...         ...             ...
# 548   122139x0   6/27/2019       NaN         NaN  Clinical Trial
# 549   122701x0   12/1/2017       NaN         NaN  Clinical Trial
# ...

# %%
df_study['INDDID']=df_study['INDDID'].str.replace(".0","")
# Out:
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_8739/1395265853.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_study['INDDID']=df_study['INDDID'].str.replace(".0","")

# %%
df_study
# Out:
#       INDDID     PETDate  AgeatPET     StudyID     PETProtocol  \
# 0     126535   8/10/2022      69.0         NaN           ABCD2
# 1     128147    9/1/2022      68.0  844403-006           ABCD2
# 2     128279    8/2/2022      70.0  844403-002           ABCD2
# 3     128281    7/6/2022      75.0  844403-001           ABCD2
# 4       1281   8/24/2022      88.0         NaN           ABCD2
# ..       ...         ...       ...         ...             ...
# 548   122139   6/27/2019       NaN         NaN  Clinical Trial
# 549     1221   12/1/2017       NaN         NaN  Clinical Trial
# 550   122946  12/15/2017       NaN         NaN  Clinical Trial
# 551  1112751   5/14/2019       NaN         NaN            ADNI
# 552     1215   4/26/2017       NaN         NaN           IDEAS
#
#             PETScannerUsed  PI-2620_Group                    PETTracer  \
# 0    Philips Ingenuity PET            NaN  AV1451 (tau) Penn Cyclotron
# ...

# %%
# 118923, 09/25/2017
df_study.loc[df_study['PETDate']=='9/25/2017']
# Out:
#      INDDID    PETDate  AgeatPET  StudyID         PETProtocol  \
# 491  118923  9/25/2017      67.0  9302601  REVEAL-SCAN 825741
#
#             PETScannerUsed  PI-2620_Group              PETTracer Unnamed: 8
# 491  Philips Ingenuity PET            NaN  Florbetapir (amyloid)        NaN

# %%
# 119035, 08/01/2017
df_study.loc[df_study['PETDate']=='8/1/2017']
# Out:
#      INDDID   PETDate  AgeatPET  StudyID         PETProtocol  \
# 238  117358  8/1/2017      72.0   API-15            NACC_API
# 492  119035  8/1/2017      73.0  9302301  REVEAL-SCAN 825741
#
#             PETScannerUsed  PI-2620_Group              PETTracer Unnamed: 8
# 238  Philips Ingenuity PET            NaN  Florbetaben (amyloid)        NaN
# 492  Philips Ingenuity PET            NaN  Florbetapir (amyloid)        NaN

# %%
# 124305x20190313xFBBPETx session to: 124305x20190313xFBBPETxABC
df_study.loc[df_study['PETDate']=='3/13/2019']
# Out:
#      INDDID    PETDate  AgeatPET  StudyID         PETProtocol  \
# 507  124305  3/13/2019      71.0  9310801  REVEAL-SCAN 825741
#
#             PETScannerUsed  PI-2620_Group              PETTracer Unnamed: 8
# 507  Philips Ingenuity PET            NaN  Florbetapir (amyloid)        NaN

# %%
df_study.loc[df_study['INDDID']=='115582.02']
# Out:
# Empty DataFrame
# Columns: [INDDID, PETDate, AgeatPET, StudyID, PETProtocol, PETScannerUsed, PI-2620_Group, PETTracer, Unnamed: 8]
# Index: []

# %%
df_study[df_study.duplicated(subset=['INDDID','PETDate'],keep=False)]
# dftodo[dftodo.duplicated
# Out:
#      INDDID    PETDate  AgeatPET  StudyID         PETProtocol  \
# 55   111275   6/5/2019      74.0      NaN                ADNI
# 75   111275  5/14/2019      74.0      NaN                ADNI
# 77   111487  4/23/2019      70.0      NaN                ADNI
# 197  105476   5/3/2018      79.0   API-60            NACC_API
# 202  106721  10/3/2017      85.0   API-27            NACC_API
# 484  115582  5/12/2017      69.0  9301501  REVEAL-SCAN 825741
# 517  106721  10/3/2017       NaN      NaN            NACC_API
# 519  115582  5/12/2017       NaN      NaN  REVEAL-SCAN 825741
# 526  105476   5/3/2018       NaN      NaN            NACC_API
# 530  111487  4/23/2019       NaN      NaN                ADNI
# 542  122701  12/1/2017       NaN      NaN      Clinical Trial
# 543  122139  6/27/2019       NaN      NaN      Clinical Trial
# 544  119655   1/3/2019       NaN      NaN      Clinical Trial
# 545  111275   6/5/2019       NaN      NaN                ADNI
# ...

# %%
#inddid as string but keep decimal points?
#or replace csv decimals with x to match to session ids

# %%
dfrename=pd.read_csv('renamePetPairs.csv')
dfrename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   old     95 non-null     object
#  1   new     95 non-null     object
# dtypes: object(2)
# memory usage: 1.6+ KB

# %%
dfrenamematch = dfrename.loc[dfrename['old'] == '101162x20171130xAV1451PETx']

# %%
dfrenamematch['new']
# Out:
# 65    101162x20171130xAV1451PETxABC
# Name: new, dtype: object

# %%
dfrenamematch['new'].iloc[0]
# Out:
# '101162x20171130xAV1451PETxABC'
